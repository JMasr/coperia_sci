# %%
import pandas as pd
from pathlib import Path

# %%
ROOT_PATH = Path(r'C:\Users\jmram\OneDrive\Documents\GitHub\coperia_tdd\data')
coperia_df = pd.read_csv(ROOT_PATH / 'coperia_metadata.csv')
coperia_df
# Out:
#                                             patient_id       patient_type  \
# 0     1848560680d-b7b0077c-b059-4c72-a3d6-fc05f18739ff      covid-control
# 1     1848560680d-b7b0077c-b059-4c72-a3d6-fc05f18739ff      covid-control
# 2     1848560680d-b7b0077c-b059-4c72-a3d6-fc05f18739ff      covid-control
# 3     18486282fe2-1d4c0df2-25c3-458e-b44c-b05fc15f6ce7      covid-control
# 4     18486282fe2-1d4c0df2-25c3-458e-b44c-b05fc15f6ce7      covid-control
# ...                                                ...                ...
# 2845  186129455cb-d6d92efb-edb4-4875-9038-e800760d8a6e      coperia-rehab
# 2846  186129455cb-d6d92efb-edb4-4875-9038-e800760d8a6e      coperia-rehab
# 2847  186129455cb-d6d92efb-edb4-4875-9038-e800760d8a6e      coperia-rehab
# 2848  186129455cb-d6d92efb-edb4-4875-9038-e800760d8a6e      coperia-rehab
# 2849  185da0265a8-827181dd-f084-4c7a-9d29-3636cb176791  covid-persistente
#
#       age  gender                              audio_id  covid  long_covid  \
# 0      49  female  c6b9296a-eed4-4c54-9c80-ecf715a90b6b    NaN       False
# 1      49  female  462f6e89-c12e-4e76-9916-17748f342472    NaN       False
# 2      49  female  b4f0aa5a-2959-46c6-9fd5-5019b74b85d6    NaN       False
# 3      56  female  89cdb797-f77c-464f-8b7b-304f0d509528    NaN       False
# 4      56  female  3b7b679d-1f2d-43bc-ba13-4f870cd7299e    NaN       False
# ...   ...     ...                                   ...    ...         ...
# 2845   53  female  d4d591aa-d9bd-4172-868e-5017ce0739b8    NaN        True
# 2846   53  female  66bc1b7a-582e-43a5-93fc-054853896172    NaN        True
# 2847   53  female  7883360d-8a01-4c70-a4c0-8012d396d2e0    NaN        True
# 2848   53  female  6f7a0f6c-6bc8-4cbb-a347-a389171b936f    NaN        True
# 2849   53  female  914a472a-4065-4247-89ce-3599f7dce9b0    NaN        True
#
#      audio_type audio_moment audio_code duration
# 0       /cough/       before    84435-7    3,007
# 1       /cough/       before    84435-7    4,003
# 2       /cough/       before    84435-7    3,006
# 3       /cough/        after    84435-7    2,006
# 4       /cough/        after    84435-7    3,003
# ...         ...          ...        ...      ...
# 2845        /a/        after    84728-5   11,004
# 2846        /a/        after    84728-5   13,017
# 2847        /a/        after    84728-5   12,004
# 2848        /a/        after    84728-5   12,993
# 2849        /a/       before    84728-5      5,0
#
# [2850 rows x 11 columns]

# %%
# Change the NaN values to False
coperia_df['covid'] = False

# Cast column duration to float
for i in coperia_df.index:
    duration_value = coperia_df.at[i, 'duration']
    if isinstance(duration_value, str): 
        float_number_as_string_with_comma = duration_value
        float_number_as_string_with_dot = float_number_as_string_with_comma.replace(',', '.')
        coperia_df.at[i, 'duration'] = float(float_number_as_string_with_dot)
    
    if duration_value == 0.0:
        print(f"Data Inconsistent at Index: {i} - {coperia_df.at[i, 'audio_id']} - {duration_value}")
        

coperia_df['age'] = coperia_df['age'].astype(int)
coperia_df['covid'] = coperia_df['covid'].astype(bool)
coperia_df['duration'] = coperia_df['duration'].astype(float)
coperia_df['long_covid'] = coperia_df['long_covid'].astype(bool)

# Change the value of the column duration using the audio_id column value
def change_a_vaule_usign_audio_id(df, audio_i, column_to_edit, value_to_change):
    original_value = df.loc[df['audio_id'] == audio_i, column_to_edit].values[0]
    if original_value == value_to_change:
        print(f"Value already changed to {value_to_change}")
    else:
        df.loc[df['audio_id'] == audio_i, column_to_edit] = value_to_change        
        
change_a_vaule_usign_audio_id(coperia_df,'7a050268-0d63-4a99-88ad-fcb86a19f976', 'duration', 0.90)
change_a_vaule_usign_audio_id(coperia_df,'832644f4-202d-4908-bc57-8631e8003c3f', 'duration', 0.90)
coperia_df.drop_duplicates(subset=['audio_id'], keep='first', inplace=True)

coperia_df
# Out:
#                                             patient_id       patient_type  \
# 0     1848560680d-b7b0077c-b059-4c72-a3d6-fc05f18739ff      covid-control
# 1     1848560680d-b7b0077c-b059-4c72-a3d6-fc05f18739ff      covid-control
# 2     1848560680d-b7b0077c-b059-4c72-a3d6-fc05f18739ff      covid-control
# 3     18486282fe2-1d4c0df2-25c3-458e-b44c-b05fc15f6ce7      covid-control
# 4     18486282fe2-1d4c0df2-25c3-458e-b44c-b05fc15f6ce7      covid-control
# ...                                                ...                ...
# 2845  186129455cb-d6d92efb-edb4-4875-9038-e800760d8a6e      coperia-rehab
# 2846  186129455cb-d6d92efb-edb4-4875-9038-e800760d8a6e      coperia-rehab
# 2847  186129455cb-d6d92efb-edb4-4875-9038-e800760d8a6e      coperia-rehab
# 2848  186129455cb-d6d92efb-edb4-4875-9038-e800760d8a6e      coperia-rehab
# 2849  185da0265a8-827181dd-f084-4c7a-9d29-3636cb176791  covid-persistente
#
#       age  gender                              audio_id  covid  long_covid  \
# 0      49  female  c6b9296a-eed4-4c54-9c80-ecf715a90b6b  False       False
# 1      49  female  462f6e89-c12e-4e76-9916-17748f342472  False       False
# 2      49  female  b4f0aa5a-2959-46c6-9fd5-5019b74b85d6  False       False
# 3      56  female  89cdb797-f77c-464f-8b7b-304f0d509528  False       False
# 4      56  female  3b7b679d-1f2d-43bc-ba13-4f870cd7299e  False       False
# ...   ...     ...                                   ...    ...         ...
# 2845   53  female  d4d591aa-d9bd-4172-868e-5017ce0739b8  False        True
# 2846   53  female  66bc1b7a-582e-43a5-93fc-054853896172  False        True
# 2847   53  female  7883360d-8a01-4c70-a4c0-8012d396d2e0  False        True
# 2848   53  female  6f7a0f6c-6bc8-4cbb-a347-a389171b936f  False        True
# 2849   53  female  914a472a-4065-4247-89ce-3599f7dce9b0  False        True
#
#      audio_type audio_moment audio_code  duration
# 0       /cough/       before    84435-7     3.007
# 1       /cough/       before    84435-7     4.003
# 2       /cough/       before    84435-7     3.006
# 3       /cough/        after    84435-7     2.006
# 4       /cough/        after    84435-7     3.003
# ...         ...          ...        ...       ...
# 2845        /a/        after    84728-5    11.004
# 2846        /a/        after    84728-5    13.017
# 2847        /a/        after    84728-5    12.004
# 2848        /a/        after    84728-5    12.993
# 2849        /a/       before    84728-5     5.000
#
# [2775 rows x 11 columns]

# %%
coperia_df.to_csv(ROOT_PATH / 'coperia_metadata_v2.csv', index=False, decimal=',', sep=';')
